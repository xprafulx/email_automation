# %%
import smtplib
import pandas as pd
import os
import time
import requests
import sys
import subprocess
import time
import requests
import ollama
import pdfplumber
from pydantic import BaseModel, Field, ValidationError
from typing import List, Literal, Optional
from tqdm import tqdm
from dotenv import load_dotenv
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.mime.application import MIMEApplication
MODEL_NAME = "qwen2.5:3b"

# %%
def start_ollama():
    """Starts the Ollama server and waits for it to become ready."""
    import subprocess, time, requests
    # Start the server as a background process
    p = subprocess.Popen(["ollama", "serve"])
    print("🚀 Starting Ollama server...")
    # Poll the API endpoint until it's ready
    for _ in range(30):
        try:
            r = requests.get("http://localhost:11434/api/tags", timeout=1)
            if r.status_code == 200:
                print("✅ Ollama server is live and ready.")
                return p
        except (requests.exceptions.ConnectionError, requests.exceptions.ReadTimeout):
            time.sleep(1)
    raise RuntimeError("Ollama server did not start within the expected time.")

# Start the server
server_process = start_ollama()

# NOTE on GPU VRAM:
# The qwen3:latest model (~5GB quantized) runs comfortably on a T4 GPU with 16GB VRAM.
# If you encounter out-of-memory errors, you can switch MODEL_NAME to "qwen3:4b".
# Out:
# 🚀 Starting Ollama server...
# ✅ Ollama server is live and ready.

# %%
# -------------------- LOAD ENV --------------------
load_dotenv()
EMAIL_ADDRESS = os.getenv("EMAIL_ADDRESS")
EMAIL_PASSWORD = os.getenv("EMAIL_PASSWORD")

if not EMAIL_ADDRESS or not EMAIL_PASSWORD:
    raise RuntimeError("Missing EMAIL_ADDRESS or EMAIL_PASSWORD in .env")

# -------------------- FILE PATHS --------------------
CSV_FILE = "email.csv"   # columns: email, company, job_description
CV_FILE = "CV.pdf"
LOG_FILE = "log.txt"
CV_TEXT = ""

# -------------------- SMTP --------------------
SMTP_SERVER = "smtp.gmail.com"
SMTP_PORT = 587
EMAIL_DELAY = 7

# %%
df = pd.read_csv(CSV_FILE)

# %%
with pdfplumber.open(CV_FILE) as pdf:
    for page in pdf.pages:
        text = page.extract_text()
        if text:
            CV_TEXT += text + "\n"  # keep spacing between pages
cv_summary = CV_TEXT
# Out:
# Error: listen tcp 127.0.0.1:11434: bind: address already in use

# %%
responses = []

for _, row in df.iterrows():
    jf = row['job_description']
    company = row['company']

    prompt = f"""
Write a short job application email based on the job description:
{jf}

From my CV, these key points are relevant to the role:
{cv_summary}

RULES:
- Start with Dear Hiring Manager
- Second line should be I hope you are well.
- End with "Kindest regards," followed by your full name on the next line: Praful Shrestha
- Use double spacing between paragraphs, leave a blank line between each paragraph
- Keep sentences 15–18 words long
- Mostly one or two syllable words
- Words of three+ syllables ≤15% of all words
- 90%+ sentences in active voice
- Mention at least one requirement from the job description
- Include the company name: {df['company']}
- Pick 2–3 key points from my CV and explain why they make me suitable
- Add motivation: why I want to work at this company
- Include how I can help the company or be beneficial in this role
- Keep it concise (~150–200 words)
- Simple English, polite ending

Applicant:
Praful Shrestha
Student at Aalborg University
Flexible working hours
"""



    try:
        response = ollama.chat(model=MODEL_NAME,
                           messages = [{'role': 'user', 'content': prompt}],
                           stream=False,
                           think=False)
        responses.append(response['message']['content'])
        time.sleep(1)
    except Exception as e:
        print(f"AI generation failed for job: {jf}\n{e}")
        responses.append("I am interested in this job opportunity.")
df['response'] = responses

# %%
pd.set_option('display.max_colwidth', None)

# %%
df['response']
# Out:
# 0    Dear Hiring Manager,\n\nI hope you are well.\n\nAs a motivated and detail-oriented student at Aalborg University with hands-on experience in Python-based data analysis, I am excited to apply for the Student Assistant Data and AI Engineer position at Everllence. My background in predictive modeling and data visualization aligns perfectly with the need to gather insights and digitalize processes within different areas like product costing and quality assessment.\n\nMy key skills include programming languages such as Python, R, and Java, which I have used extensively for data preprocessing, cleaning, and analysis. Additionally, I am proficient in tools like Jupyter Notebook, Visual Studio Code, Excel, and Power BI, enabling me to develop machine learning models and create reports effectively.\n\nEverllence’s focus on innovation and the integration of AI technologies is deeply aligned with my interests and skills. I look forward to applying these to support the digitalization of product development processes at Engine Lifecycle Management organization. My strong analytical skills and experience in data engineering workflows will be instrumental in designing, implementing custom AI agents and automation solutions.\n\nI am eager to contribute by collaborating with Power Platform software developers to ensure seamless integration of AI modules into successful applications. I also aim to support a wide range of AI projects such as chatbots and intelligent document processing, thereby making a significant impact on the organization’s operations.\n\nI am particularly drawn to Everllence's commitment to diversity and inclusion, which has been evident in its inclusive recruitment process. The opportunity to connect my education with practical experience within your esteemed company is incredibly appealing. I believe that this role will be a stepping stone for me as a future leader in data and AI technologies.\n\nThank you for considering my application. I am excited about the prospect of joining Everllence and contributing to its success.\n\nKindest regards,\n\nPraful Shrestha
# 1                                                                                                                                                                                                             Dear Hiring Manager,\n\nI hope you are well.\n\nAs a seasoned Business Central Software Engineer with 6+ years of experience in developing financial solutions using AL, I am excited about the opportunity to join your innovative team. My background in Python-based data analysis and strong understanding of financial processes make me an ideal fit for this role.\n\nDuring my time as a Relationship Associate at SmartMove Nepal (Apr 2025 - Jul 2025), I managed client relationships, ensuring smooth communication and timely updates. This experience helped me develop excellent communication skills and teamwork abilities. My work also involved collecting documents, conducting loan eligibility research, preparing product comparisons, and overseeing the entire loan application process.\n\nIn my role as an Accountant at Sajo Packaging Industry Pvt. Ltd. (Dec 2022 - May 2023), I maintained accurate financial records and ensured compliance with VAT regulations. This experience sharpened my analytical mindset and attention to detail, which are crucial for developing high-quality code in the agile environment you described.\n\nMy hands-on experience with Python-based data analysis projects and strong understanding of Business Central have prepared me well for this position. Additionally, my knowledge of Jupyter Notebook, Visual Studio Code, Excel, BrokerEngine, Flex, Quickly, LastPass, and Scikit-learn are a significant asset to your team.\n\nI am motivated to work at 0 sanam as I believe in the company's mission of developing innovative financial solutions used worldwide. My goal is to contribute by designing and building new functionalities for Business Central Finance modules while ensuring clean, efficient, and well-tested code. I also bring an analytical mindset and a passion for smart financial solutions that align with your team’s values.\n\nKindest regards,\n\nPraful Shrestha
# 2                                                                                                        Dear Hiring Manager,\n\nI hope you are well.\n\nI am writing to express my interest in the Revenue Finance Analyst position at AVEVA. With a background in business data science and strong analytical skills, I believe I would be an ideal fit for this role. My experience with Python-based data analysis and hands-on projects have equipped me with the analytical competency and proficiency in Excel needed to support AVEVA’s revenue processes.\n\nAt Aalborg University, where I am currently pursuing a Master's degree in Business Data Science, I developed a strong foundation in predictive modeling and data visualization using tools like Pandas, NumPy, and Scikit-learn. These skills are crucial for understanding and improving global end-to-end business processes as outlined in the job description.\n\nI have experience with several systems including Navision, SAP, Oracle, and Zuora, which aligns well with the requirement of understanding IT interaction between process and related systems. I am also experienced in ERP migration projects and transforming financial processes to meet both US GAAP and Sarbanes-Oxley standards. These skills make me confident in designing standardised end-to-end revenue processes that are compliant with PCAOB requirements.\n\nI have a proven track record of managing and balancing conflicting priorities, ensuring timely delivery of tasks while maintaining high-quality work. My communication skills allow me to interact effectively at all levels within the organization. I am particularly interested in joining AVEVA because your commitment to transparency and innovation aligns closely with my own values and career goals.\n\nI am eager to contribute to AVEVA’s mission of creating transformative technology that empowers customers to engineer a better world. I believe my analytical background, coupled with my experience in financial systems, will enable me to excel in this role. Thank you for considering my application. \n\nKindest regards,\nPraful Shrestha
# Name: response, dtype: object

# %%
# Connect to SMTP server
server = smtplib.SMTP(SMTP_SERVER, SMTP_PORT)
server.starttls()
server.login(EMAIL_ADDRESS, EMAIL_PASSWORD)

# -------------------- SEND EMAILS --------------------
with open(LOG_FILE, "w") as log_file:
    for _, row in df.iterrows():
        try:
            company_name = row['company'].strip().title()
            recipient_email = row['email']

            # Create email
            msg = MIMEMultipart()
            msg["From"] = EMAIL_ADDRESS
            msg["To"] = recipient_email
            msg["Subject"] = "Job Application"

            # Attach email body
            body = row['response']
            msg.attach(MIMEText(body, "plain"))

            # Attach CV
            with open(CV_FILE, "rb") as f:
                part = MIMEApplication(f.read(), Name=CV_FILE)
                part['Content-Disposition'] = f'attachment; filename="{CV_FILE}"'
                msg.attach(part)

            # Send email
            server.send_message(msg)
            print(f"Sent to {recipient_email} ({company_name})")
            log_file.write(f"SUCCESS: {recipient_email} ({company_name})\n")

            # Delay to avoid spam detection
            time.sleep(EMAIL_DELAY)

        except Exception as e:
            print(f"FAILED: {recipient_email} ({company_name}) - {e}")
            log_file.write(f"FAILED: {recipient_email} ({company_name}) - {e}\n")
            traceback.print_exc()

server.quit()
print("All emails processed. Check log.txt for details.")
# Out:
# Sent to sanammhrjn19@gmail.com (Sanam)
# Sent to Tenashastha@gmail.com (Tenasha)
# Sent to sthpraful19@gmail.com (Praful)
# All emails processed. Check log.txt for details.
